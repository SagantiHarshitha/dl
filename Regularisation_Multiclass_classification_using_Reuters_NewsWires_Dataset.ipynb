# %% [markdown]
# <a href="https://colab.research.google.com/github/SagantiHarshitha/dl/blob/main/Regularisation_Multiclass_classification_using_Reuters_NewsWires_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]

# %%
model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 94ms/step - loss: 2.7333 - categorical_accuracy: 0.4851 - val_loss: 1.8473 - val_categorical_accuracy: 0.5962
# Epoch 2/25
# 16/16 [==============================] - 1s 87ms/step - loss: 1.6078 - categorical_accuracy: 0.6528 - val_loss: 1.3940 - val_categorical_accuracy: 0.6837
# Epoch 3/25
# 16/16 [==============================] - 1s 67ms/step - loss: 1.2327 - categorical_accuracy: 0.7314 - val_loss: 1.1884 - val_categorical_accuracy: 0.7375
# Epoch 4/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.0089 - categorical_accuracy: 0.7788 - val_loss: 1.0875 - val_categorical_accuracy: 0.7538
# Epoch 5/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.8367 - categorical_accuracy: 0.8187 - val_loss: 1.0154 - val_categorical_accuracy: 0.7800
# Epoch 6/25
# 16/16 [==============================] - 1s 52ms/step - loss: 0.7017 - categorical_accuracy: 0.8487 - val_loss: 0.9682 - val_categorical_accuracy: 0.7925
# Epoch 7/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.5925 - categorical_accuracy: 0.8726 - val_loss: 0.9370 - val_categorical_accuracy: 0.8012
# Epoch 8/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.5003 - categorical_accuracy: 0.8955 - val_loss: 0.9057 - val_categorical_accuracy: 0.8100
# Epoch 9/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.4238 - categorical_accuracy: 0.9102 - val_loss: 0.8804 - val_categorical_accuracy: 0.8100
# Epoch 10/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.3619 - categorical_accuracy: 0.9208 - val_loss: 0.8738 - val_categorical_accuracy: 0.8175
# Epoch 11/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.3148 - categorical_accuracy: 0.9314 - val_loss: 0.8866 - val_categorical_accuracy: 0.8087
# Epoch 12/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.2700 - categorical_accuracy: 0.9402 - val_loss: 0.8802 - val_categorical_accuracy: 0.8087
# Epoch 13/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2430 - categorical_accuracy: 0.9434 - val_loss: 0.8866 - val_categorical_accuracy: 0.8037
# Epoch 14/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2162 - categorical_accuracy: 0.9466 - val_loss: 0.8758 - val_categorical_accuracy: 0.8250
# Epoch 15/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1950 - categorical_accuracy: 0.9504 - val_loss: 0.8925 - val_categorical_accuracy: 0.8100
# Epoch 16/25
# 16/16 [==============================] - 1s 88ms/step - loss: 0.1850 - categorical_accuracy: 0.9503 - val_loss: 0.9203 - val_categorical_accuracy: 0.8062
# Epoch 17/25
# 16/16 [==============================] - 1s 85ms/step - loss: 0.1660 - categorical_accuracy: 0.9556 - val_loss: 0.9086 - val_categorical_accuracy: 0.8138
# Epoch 18/25
# 16/16 [==============================] - 1s 53ms/step - loss: 0.1524 - categorical_accuracy: 0.9550 - val_loss: 0.9392 - val_categorical_accuracy: 0.8012
# Epoch 19/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1483 - categorical_accuracy: 0.9554 - val_loss: 0.9389 - val_categorical_accuracy: 0.7950
# Epoch 20/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1343 - categorical_accuracy: 0.9572 - val_loss: 0.9310 - val_categorical_accuracy: 0.8138
# Epoch 21/25
# 16/16 [==============================] - 1s 52ms/step - loss: 0.1347 - categorical_accuracy: 0.9588 - val_loss: 0.9608 - val_categorical_accuracy: 0.8012
# Epoch 22/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1260 - categorical_accuracy: 0.9582 - val_loss: 0.9746 - val_categorical_accuracy: 0.8037
# Epoch 23/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1205 - categorical_accuracy: 0.9591 - val_loss: 0.9815 - val_categorical_accuracy: 0.8075
# Epoch 24/25
# 16/16 [==============================] - 1s 52ms/step - loss: 0.1215 - categorical_accuracy: 0.9582 - val_loss: 0.9991 - val_categorical_accuracy: 0.8025
# Epoch 25/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1149 - categorical_accuracy: 0.9589 - val_loss: 1.0120 - val_categorical_accuracy: 0.7987

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
